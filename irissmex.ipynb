# %%
# %matplotlib inline

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
# %run irissmex.py
# Out:
# ****Training****
#
#
# Weight Matrix
#  [[ 150.45832125  150.52556785  150.46796318]
#  [  -0.41336885   -0.53830757   -0.45521707]
#  [   3.08136427    2.79934601    3.04573878]
#  [  -2.01263636   -1.12879175   -1.77016776]
#  [  -1.35647373   -1.77006139   -0.81759942]]
#
# Error
#  0.773777591962
# ╒═══════════════════════════════════════╤═══════════════════╤════════════════╕
# │ Probability                           │   Predicted Class │   Actual Class │
# ╞═══════════════════════════════════════╪═══════════════════╪════════════════╡
# │ [ 0.55263462  0.23280932  0.21455607] │                 0 │              0 │
# ├───────────────────────────────────────┼───────────────────┼────────────────┤
# │ [ 0.29316932  0.34948416  0.35734652] │                 2 │              1 │
# ├───────────────────────────────────────┼───────────────────┼────────────────┤
# │ [ 0.21033905  0.22529578  0.56436517] │                 2 │              2 │
# ...
