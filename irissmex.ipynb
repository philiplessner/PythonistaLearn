# %%
# %matplotlib inline

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
# %run irissmex.py
# Out:
# ****Training****
#
#
# Weight Matrix
#  [[  1.50148567e+02   1.50129252e+02   1.50215870e+02]
#  [  5.52938955e-02  -9.58864961e-02   3.39968733e-02]
#  [  3.73101407e+00   3.48336461e+00   3.67699967e+00]
#  [ -1.58250803e+00  -7.59691973e-01  -1.31952855e+00]
#  [ -4.59332345e-01  -7.61590733e-01   8.95121235e-02]]
#
# Error
#  0.764404636258
# ╒═══════════════════════════════════════╤═══════════════════╤════════════════╕
# │ Probability                           │   Predicted Class │   Actual Class │
# ╞═══════════════════════════════════════╪═══════════════════╪════════════════╡
# │ [ 0.29110182  0.44012739  0.26877078] │                 1 │              1 │
# ├───────────────────────────────────────┼───────────────────┼────────────────┤
# │ [ 0.19784541  0.29772918  0.50442541] │                 2 │              2 │
# ├───────────────────────────────────────┼───────────────────┼────────────────┤
# │ [ 0.19067981  0.20200903  0.60731116] │                 2 │              2 │
# ...

# %%
# %run linregex1.py
# Out:
# ****Minibatch Gradient Descent****
#
# --Training--
#
#
# Hyperparamters
#
# adaptive 	 0.99
# minibatches 	 1
# epochs 	 300
# eta 	 0.3
#
# Number of Training Examples:  6441
# Coefficients	 [  4.54339856e+02  -1.44978587e+01  -3.21619632e+00   4.28198640e-01
#   -2.15933020e+00]
# h_theta0 	 443.516432521
# h_theta1 	 -1.93978356445
# h_theta2 	 -0.2525092638
# h_theta3 	 0.0725659617668
# h_theta4 	 -0.147265643061
# R**2	 0.93000190044
#
# --Testing--
# R**2	 0.925620841575

# %%
# %run dsfslogex.py
# Out:
# ****Minibatch Gradient Descent****
#
# --Training--
#
# [-2.04125539  4.8521252  -4.56202   ]
# [  8.74328201e+00   1.68781331e+00  -2.89544778e-04]
# ╒═══════════════╤═══════════════════╤════════════════╕
# │   Probability │   Predicted Class │   Actual Class │
# ╞═══════════════╪═══════════════════╪════════════════╡
# │   0.0184621   │                 0 │              1 │
# ├───────────────┼───────────────────┼────────────────┤
# │   0.0824721   │                 0 │              0 │
# ├───────────────┼───────────────────┼────────────────┤
# │   0.0416768   │                 0 │              0 │
# ├───────────────┼───────────────────┼────────────────┤
# │   0.434253    │                 0 │              0 │
# ├───────────────┼───────────────────┼────────────────┤
# │   0.353538    │                 0 │              0 │
# ├───────────────┼───────────────────┼────────────────┤
# │   0.35321     │                 0 │              1 │
# ...
