# %%
ll
# Out:
# total 200
# -rw-rw-r-- 1 philiplessner   2244 Apr 29 01:27 NNplay.py
# -rw-rw-r-- 1 philiplessner     24 Apr 23 11:46 README.md
# drwxrwxr-x 2 philiplessner   4096 Apr 29 01:28 __pycache__/
# drwxrwxr-x 2 philiplessner   4096 Apr 23 12:01 data/
# -rw-rw-r-- 1 philiplessner   4975 Apr 22 20:51 dsfslogex.py
# -rw-rw-r-- 1 philiplessner   2667 Apr 22 20:51 dsfsnnex.py
# -rw-rw-r-- 1 philiplessner   2055 Apr 22 20:51 fgd.py
# -rw-rw-r-- 1 philiplessner   1426 Apr 22 20:51 getmnist.py
# -rw-rw-r-- 1 philiplessner   1447 Apr 22 20:51 glm.py
# -rw-rw-r-- 1 philiplessner   2178 Apr 22 20:51 irisnnex.py
# -rw-rw-r-- 1 philiplessner   1081 Apr 22 20:51 linreg.py
# -rw-rw-r-- 1 philiplessner   1958 Apr 22 20:51 linregex1.py
# -rw-rw-r-- 1 philiplessner    631 Apr 22 20:51 logreg.py
# -rw-rw-r-- 1 philiplessner   2648 Apr 22 20:51 metrics.py
# -rw-rw-r-- 1 philiplessner   1092 Apr 22 20:51 ml_util.py
# -rw-rw-r-- 1 philiplessner 115839 Apr 29 01:29 mnistnnex.ipynb
# ...

# %%
# %matplotlib inline

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
# %run mnistnnex.py
# Out:
# Rows: 60000, columns: 784
# Rows: 10000, columns: 784
# ****Training****
#
# --Hyperameters--
# eta : 0.005
# epochs : 500
# minibatches : 20
# decrease_rate : 1e-05
# nhidden : 100
#
# Training Time: 276.6604244709015 sec
#
#
# syn0
#  [[-0.158873    0.39690538 -1.01804176 ...,  0.28781455 -1.11288906
#    0.39444864]
#  [-0.34663937  0.05367877  0.77170149 ..., -0.52987127  0.23237042
#    0.89963423]
#  [ 0.90042307  0.11286894  0.83102999 ..., -0.83934329  0.96444793
#   -0.63517271]
#  ...,
#  [-0.86837692  0.46877186  0.4686643  ..., -0.82462838 -0.04800646
#    0.1467718 ]
#  [ 0.27820323  0.22739057  0.88840856 ...,  0.6694405  -0.58584472
#    0.30015019]
#  [-0.20974842  0.73291195 -0.29036846 ..., -0.06971742  0.58521094
#   -0.90230316]]
#
# syn1
#  [[-0.0477482  -0.6665317  -0.94852295 ..., -0.22550888 -0.37830783
#    0.24897996]
#  [-1.23781623  1.15849106  0.217796   ..., -0.41893945 -1.4104928
#    1.02787646]
# ...

# %%
# %run mnistnnex.py
# Out:
# Rows: 60000, columns: 784
# Rows: 10000, columns: 784
# ****Training****
#
# --Hyperameters--
# minibatches : 20
# eta : 0.02
# epochs : 1000
# nhidden : 100
# decrease_rate : 1e-05
#
# Training Time: 550.6220500469208 sec
#
#
# syn0
#  [[-0.10927522  0.52276498 -0.99821796 ...,  0.1922974  -1.1899107
#    0.2969798 ]
#  [-0.34614339  0.05493736  0.77189973 ..., -0.53082644  0.2316002
#    0.89865954]
#  [ 0.90091905  0.11412754  0.83122823 ..., -0.84029846  0.96367771
#   -0.6361474 ]
#  ...,
#  [-0.86788094  0.47003045  0.46886253 ..., -0.82558355 -0.04877667
#    0.14579711]
#  [ 0.27869921  0.22864917  0.8886068  ...,  0.66848532 -0.58661493
#    0.2991755 ]
#  [-0.20925245  0.73417054 -0.29017022 ..., -0.07067259  0.58444073
#   -0.90327785]]
#
# syn1
#  [[-0.19155978 -0.73036789 -1.11055753 ..., -0.47735288 -0.49627371
#    0.44443398]
#  [-1.69208115  1.69133022  0.19911699 ..., -1.13050834 -1.76296465
#    1.52432799]
# ...

# %%
# %run mnistnnex.py
# Out:
# Rows: 60000, columns: 784
# Rows: 10000, columns: 784
# ****Training****
#
# --Hyperameters--
# eta : 0.01
# minibatches : 20
# nhidden : 100
# epochs : 500
# decrease_rate : 1e-05
#
# Training Time: 274.2466278076172 sec
#
#
# syn0
#  [[-0.15397718  0.30197382 -1.040717   ...,  0.26303781 -1.19202808
#    0.34136322]
#  [-0.34659041  0.05272945  0.77147474 ..., -0.53011904  0.23157903
#    0.89910338]
#  [ 0.90047203  0.11191962  0.83080324 ..., -0.83959106  0.96365654
#   -0.63570356]
#  ...,
#  [-0.86832796  0.46782254  0.46843754 ..., -0.82487615 -0.04879785
#    0.14624095]
#  [ 0.27825219  0.22644126  0.88818181 ...,  0.66919273 -0.58663611
#    0.29961933]
#  [-0.20969947  0.73196263 -0.29059521 ..., -0.06996519  0.58441955
#   -0.90283402]]
#
# syn1
#  [[ -1.91634099e-01  -6.83991930e-01  -1.05738263e+00 ...,  -2.93010501e-01
#    -4.71990037e-01   2.58354543e-01]
#  [ -1.37411650e+00   1.19109569e+00   1.96962078e-01 ...,  -7.91100284e-01
# ...

# %%
# %run mnistnnex.py
# Out:
# Rows: 60000, columns: 784
# Rows: 10000, columns: 784
# ****Training****
#
# --Hyperameters--
# decrease_rate : 0.0001
# nhidden : 100
# minibatches : 20
# epochs : 1000
# eta : 0.005
#
# Training Time: 555.8569345474243 sec
#
#
# syn0
#  [[-0.18990531  0.48041015 -0.99224792 ...,  0.32998595 -1.06490044
#    0.38625035]
#  [-0.34694969  0.05451382  0.77195943 ..., -0.52944956  0.2328503
#    0.89955225]
#  [ 0.90011275  0.11370399  0.83128793 ..., -0.83892157  0.96492782
#   -0.63525469]
#  ...,
#  [-0.86868724  0.4696069   0.46892223 ..., -0.82420667 -0.04752657
#    0.14668982]
#  [ 0.27789291  0.22822562  0.8886665  ...,  0.66986221 -0.58536483
#    0.3000682 ]
#  [-0.21005875  0.73374699 -0.29011052 ..., -0.06929571  0.58569083
#   -0.90238515]]
#
# syn1
#  [[ 0.13711346 -0.62351131 -0.9268296  ..., -0.17159904 -0.28068342
#    0.26995699]
#  [-0.83172793  1.12307101  0.16566442 ..., -0.29218675 -1.09767535
#    0.67210995]
# ...
