# %%
ll
# Out:
# total 88
# -rw-rw-r-- 1 philiplessner 2234 Apr 22 20:51 NNplay.py
# -rw-rw-r-- 1 philiplessner  214 Apr 23 14:38 Notebook.ipynb
# -rw-rw-r-- 1 philiplessner   24 Apr 23 11:46 README.md
# drwxrwxr-x 2 philiplessner 4096 Apr 23 14:22 __pycache__/
# drwxrwxr-x 2 philiplessner 4096 Apr 23 12:01 data/
# -rw-rw-r-- 1 philiplessner 4975 Apr 22 20:51 dsfslogex.py
# -rw-rw-r-- 1 philiplessner 2667 Apr 22 20:51 dsfsnnex.py
# -rw-rw-r-- 1 philiplessner 2055 Apr 22 20:51 fgd.py
# -rw-rw-r-- 1 philiplessner 1426 Apr 22 20:51 getmnist.py
# -rw-rw-r-- 1 philiplessner 1447 Apr 22 20:51 glm.py
# -rw-rw-r-- 1 philiplessner 2178 Apr 22 20:51 irisnnex.py
# -rw-rw-r-- 1 philiplessner 1081 Apr 22 20:51 linreg.py
# -rw-rw-r-- 1 philiplessner 1958 Apr 22 20:51 linregex1.py
# -rw-rw-r-- 1 philiplessner  631 Apr 22 20:51 logreg.py
# -rw-rw-r-- 1 philiplessner 2648 Apr 22 20:51 metrics.py
# -rw-rw-r-- 1 philiplessner 1092 Apr 22 20:51 ml_util.py
# -rw-rw-r-- 1 philiplessner 2839 Apr 23 14:06 mnistnnex.py
# ...

# %%
# %matplotlib inline

# %%
# %run mnistnnex.py
# Out:
# Rows: 60000, columns: 784
# Rows: 10000, columns: 784
# ****Training****
#
# Training Time: 92.16406297683716 sec
#
#
# syn0
#  [[-0.16499917  0.44159941 -1.0036816  ..., -0.4101392  -0.42328546
#   -0.74063884]
#  [-0.96030926  0.35862149 -0.58065411 ...,  0.14999148 -0.99309548
#    0.23359385]
#  [-0.34575337  0.05506663  0.76797385 ...,  0.42861046  0.12059783
#   -0.97558402]
#  ...,
#  [ 0.33723985 -0.90129335 -0.23298591 ..., -0.78753527 -0.33169836
#   -0.60263443]
#  [-0.66094148  0.99591103 -0.89734579 ..., -0.46675792 -0.78958652
#    0.96973896]
#  [ 0.57944374  0.5402248  -0.22561663 ...,  0.48878966 -0.04671793
#   -0.63965198]]
#
# b0
#  [[ 0.13022157 -0.8966117  -0.41746141  0.02321387  0.2646525   1.35195202
#   -0.36177104  0.80129776  0.12594316  0.94619237 -0.85370738 -0.54413982
#   -0.13423119 -0.04535384  0.18415628 -0.18965324  0.17663729  0.09051929
#   -0.56110522  0.65514733  0.69476084  0.34410239 -0.30811551  0.55520874
# ...
